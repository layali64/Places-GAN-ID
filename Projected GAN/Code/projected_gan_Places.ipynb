# %% [markdown]
# # Training Projected GAN
# This is a self-contained notebook for training Projected GAN.

# %% [markdown]
# ## Setup
#
# Make sure you're running a GPU runtime; if not, select "GPU" as the hardware accelerator in Runtime > Change Runtime Type in the menu.
#
# Now, get the repo and install missing dependencies.

# %%
#%cd /content/drive/MyDrive/Places/Projected-GAN
# Out:
# /content/drive/MyDrive/Places/Projected-GAN

# %%
# %%capture
# %%bash
# # clone repo
# git clone https://github.com/autonomousvision/projected_gan
# pip install timm dill

# %%
# !pip install timm dill
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.6.13-py3-none-any.whl (549 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 11.5 MB/s eta 0:00:00
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 16.1 MB/s eta 0:00:00
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.9/dist-packages (from timm) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from timm) (0.15.1+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from timm) (6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->timm) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->timm) (3.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->timm) (2.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->timm) (3.10.7)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7->timm) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7->timm) (16.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub->timm) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub->timm) (4.65.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub->timm) (23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision->timm) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->timm) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.7->timm) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub->timm) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub->timm) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub->timm) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub->timm) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: dill, huggingface-hub, timm
# Successfully installed dill-0.3.6 huggingface-hub-0.13.4 timm-0.6.13

# %%
# !pip install timm==0.5.4
# !pip install ftfy
# !pip install Ninja
# !pip install setuptools==59.5.0
# !pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio==0.9.0 -f
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm==0.5.4
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 KB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from timm==0.5.4) (0.15.1+cu118)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.9/dist-packages (from timm==0.5.4) (2.0.0+cu118)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.4->timm==0.5.4) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.4->timm==0.5.4) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.4->timm==0.5.4) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.4->timm==0.5.4) (3.10.7)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.4->timm==0.5.4) (3.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.4->timm==0.5.4) (2.0.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.5.4) (16.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.5.4) (3.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision->timm==0.5.4) (2.27.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision->timm==0.5.4) (1.22.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->timm==0.5.4) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.4->timm==0.5.4) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->timm==0.5.4) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->timm==0.5.4) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->timm==0.5.4) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->timm==0.5.4) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.4->timm==0.5.4) (1.3.0)
# Installing collected packages: timm
#   Attempting uninstall: timm
#     Found existing installation: timm 0.6.13
#     Uninstalling timm-0.6.13:
#       Successfully uninstalled timm-0.6.13
# Successfully installed timm-0.5.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy) (0.2.6)
# Installing collected packages: ftfy
# Successfully installed ftfy-6.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Ninja
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 KB 4.5 MB/s eta 0:00:00
# Installing collected packages: Ninja
# Successfully installed Ninja-1.11.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 KB 11.4 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.6.1
#     Uninstalling setuptools-67.6.1:
#       Successfully uninstalled setuptools-67.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# cvxpy 1.3.1 requires setuptools>65.5.1, but you have setuptools 59.5.0 which is incompatible.
# arviz 0.15.1 requires setuptools>=60.0.0, but you have setuptools 59.5.0 which is incompatible.
# Successfully installed setuptools-59.5.0
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# -f option requires 1 argument

# %% [markdown]
# ## Data Preparation
# We need to download and prepare the data. In this example, we use the few-shot datasets of the [FastGAN repo](https://github.com/odegeasslbc/FastGAN-pytorch).

# %%
#!gdown https://drive.google.com/u/0/uc?id=1aAJCZbXNHyraJ6Mi13dSbe7pTyfPXha0&export=download
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1aAJCZbXNHyraJ6Mi13dSbe7pTyfPXha0
# To: /content/drive/MyDrive/Places/Projected-GAN/few-shot-image-datasets.zip
# 100% 913M/913M [00:07<00:00, 124MB/s]

# %%
# %%capture
# #!unzip few-shot-image-datasets.zip
# !mv few-shot-images data

# %%
# %cd /content/drive/MyDrive/Places/Projected-GAN/projected_gan
# Out:
# /content/drive/MyDrive/Places/Projected-GAN/projected_gan

# %%
# %%bash
# python dataset_tool.py --source=/content/drive/MyDrive/Places/Dataset --dest=/content/drive/MyDrive/Places/Projected-GAN/alter-Image --resolution=256x256

# %% [markdown]
# ## Training
#
# Now that the data is prepared, we can start training!  The training loop tracks FID, but the computations seems to lead to problems in colab. Hence, it is disable by default (```metrics=[]```). The loop also generates fixed noise samples after a defined amount of ticks, eg. below ```--snap=1```.

# %%
import os
import json
import re
import dnnlib

from training import training_loop
from torch_utils import training_stats
from train import init_dataset_kwargs
from metrics import metric_main

# %%
def launch_training(c, desc, outdir, rank=0):
    # Pick output directory.
    prev_run_dirs = []
    if os.path.isdir(outdir):
        prev_run_dirs = [x for x in os.listdir(outdir) if os.path.isdir(os.path.join(outdir, x))]

    matching_dirs = [re.fullmatch(r'\d{5}' + f'-{desc}', x) for x in prev_run_dirs if re.fullmatch(r'\d{5}' + f'-{desc}', x) is not None]
    if c.restart_every > 0 and len(matching_dirs) > 0:  # expect unique desc, continue in this directory
        assert len(matching_dirs) == 1, f'Multiple directories found for resuming: {matching_dirs}'
        c.run_dir = os.path.join(outdir, matching_dirs[0].group())
    else:                     # fallback to standard
        prev_run_ids = [re.match(r'^\d+', x) for x in prev_run_dirs]
        prev_run_ids = [int(x.group()) for x in prev_run_ids if x is not None]
        cur_run_id = max(prev_run_ids, default=-1) + 1
        c.run_dir = os.path.join(outdir, f'{cur_run_id:05d}-{desc}')
        assert not os.path.exists(c.run_dir)


    # Print options.
    print()
    print('Training options:')
    print(json.dumps(c, indent=2))
    print()
    print(f'Output directory:    {c.run_dir}')
    print(f'Number of GPUs:      {c.num_gpus}')
    print(f'Batch size:          {c.batch_size} images')
    print(f'Training duration:   {c.total_kimg} kimg')
    print(f'Dataset path:        {c.training_set_kwargs.path}')
    print(f'Dataset size:        {c.training_set_kwargs.max_size} images')
    print(f'Dataset resolution:  {c.training_set_kwargs.resolution}')
    print(f'Dataset labels:      {c.training_set_kwargs.use_labels}')
    print(f'Dataset x-flips:     {c.training_set_kwargs.xflip}')
    print()

    # Create output directory.
    print('Creating output directory...')
    os.makedirs(c.run_dir, exist_ok=c.restart_every > 0)
    with open(os.path.join(c.run_dir, 'training_options.json'), 'wt+') as f:
        json.dump(c, f, indent=2)

    # Start training
    dnnlib.util.Logger(file_name=os.path.join(c.run_dir, 'log.txt'), file_mode='a', should_flush=False)
    sync_device = torch.device('cuda', rank) if c.num_gpus > 1 else None
    training_stats.init_multiprocessing(rank=rank, sync_device=sync_device)
    training_loop.training_loop(rank=rank, **c)

# %%
def train(**kwargs):
    # Initialize config.
    opts = dnnlib.EasyDict(kwargs) # Command line arguments.
    c = dnnlib.EasyDict() # Main config dict.
    c.G_kwargs = dnnlib.EasyDict(class_name=None, z_dim=64, w_dim=128, mapping_kwargs=dnnlib.EasyDict())
    c.G_opt_kwargs = dnnlib.EasyDict(class_name='torch.optim.Adam', betas=[0,0.99], eps=1e-8)
    c.D_opt_kwargs = dnnlib.EasyDict(class_name='torch.optim.Adam', betas=[0,0.99], eps=1e-8)
    c.data_loader_kwargs = dnnlib.EasyDict(pin_memory=True, prefetch_factor=2)

    # Training set.
    c.training_set_kwargs, dataset_name = init_dataset_kwargs(data=opts.data)
    if opts.cond and not c.training_set_kwargs.use_labels:
        raise ValueError('--cond=True requires labels specified in dataset.json')
    c.training_set_kwargs.use_labels = opts.cond
    c.training_set_kwargs.xflip = opts.mirror

    # Hyperparameters & settings.
    c.num_gpus = opts.gpus
    c.batch_size = opts.batch
    c.batch_gpu = opts.batch_gpu or opts.batch // opts.gpus
    c.G_kwargs.channel_base = opts.cbase
    c.G_kwargs.channel_max = opts.cmax
    c.G_kwargs.mapping_kwargs.num_layers = 2
    c.G_opt_kwargs.lr = (0.002 if opts.cfg == 'stylegan2' else 0.0025) if opts.glr is None else opts.glr
    c.D_opt_kwargs.lr = opts.dlr
    c.metrics = opts.metrics
    c.total_kimg = opts.kimg
    c.kimg_per_tick = opts.tick
    c.image_snapshot_ticks = c.network_snapshot_ticks = opts.snap
    c.random_seed = c.training_set_kwargs.random_seed = opts.seed
    c.data_loader_kwargs.num_workers = opts.workers

    # Sanity checks.
    if c.batch_size % c.num_gpus != 0:
        raise ValueError('--batch must be a multiple of --gpus')
    if c.batch_size % (c.num_gpus * c.batch_gpu) != 0:
        raise ValueError('--batch must be a multiple of --gpus times --batch-gpu')
    if any(not metric_main.is_valid_metric(metric) for metric in c.metrics):
        raise ValueError('\n'.join(['--metrics can only contain the following values:'] + metric_main.list_valid_metrics()))

    # Base configuration.
    c.ema_kimg = c.batch_size * 10 / 32
    if opts.cfg == 'stylegan2':
        c.G_kwargs.class_name = 'pg_modules.networks_stylegan2.Generator'
        c.G_kwargs.fused_modconv_default = 'inference_only' # Speed up training by using regular convolutions instead of grouped convolutions.
        use_separable_discs = True

    elif opts.cfg == 'fastgan':
        c.G_kwargs = dnnlib.EasyDict(class_name='pg_modules.networks_fastgan.Generator', cond=opts.cond)
        c.G_opt_kwargs.lr = c.D_opt_kwargs.lr = 0.0002
        use_separable_discs = False

    # Restart.
    c.restart_every = opts.restart_every

    # Description string.
    desc = f'{opts.cfg:s}-{dataset_name:s}-gpus{c.num_gpus:d}-batch{c.batch_size:d}'
    if opts.desc is not None:
        desc += f'-{opts.desc}'

    # Projected and Multi-Scale Discriminators
    c.loss_kwargs = dnnlib.EasyDict(class_name='training.loss.ProjectedGANLoss')
    c.D_kwargs = dnnlib.EasyDict(
        class_name='pg_modules.discriminator.ProjectedDiscriminator',
        diffaug=True,
        interp224=(c.training_set_kwargs.resolution < 224),
        backbone_kwargs=dnnlib.EasyDict(),
    )

    c.D_kwargs.backbone_kwargs.cout = 64
    c.D_kwargs.backbone_kwargs.expand = True
    c.D_kwargs.backbone_kwargs.proj_type = 2
    c.D_kwargs.backbone_kwargs.num_discs = 4
    c.D_kwargs.backbone_kwargs.separable = use_separable_discs
    c.D_kwargs.backbone_kwargs.cond = opts.cond

    # Launch.
    launch_training(c=c, desc=desc, outdir=opts.outdir)

# %%
# start training!

train(
    outdir='training-runs', 
    cfg='fastgan',
    data='/content/drive/MyDrive/Places/LUSN_dataset_bedroom/lsun_train_output_dir', 
    gpus=1, 
    batch=64, 
    cond=False, 
    mirror=1, 
    batch_gpu=8, 
    cbase=32768, 
    cmax=512, 
    glr=None, 
    dlr=0.002, 
    desc='', 
    metrics=[],
    kimg=10000, 
    tick=4, 
    snap=1, 
    seed=0, 
    workers=1,
    restart_every=999999,
)
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "pg_modules.networks_fastgan.Generator",
#     "cond": false
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0002
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0002
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "prefetch_factor": 2,
#     "num_workers": 1
#   },
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/Places/LUSN_dataset_bedroom/lsun_train_output_dir",
#     "use_labels": false,
#     "max_size": 8098,
#     "xflip": 1,
#     "resolution": 256,
#     "random_seed": 0
#   },
#   "num_gpus": 1,
#   "batch_size": 64,
#   "batch_gpu": 8,
#   "metrics": [],
#   "total_kimg": 10000,
#   "kimg_per_tick": 4,
#   "image_snapshot_ticks": 1,
#   "network_snapshot_ticks": 1,
#   "random_seed": 0,
#   "ema_kimg": 20.0,
#   "restart_every": 999999,
#   "loss_kwargs": {
#     "class_name": "training.loss.ProjectedGANLoss"
#   },
#   "D_kwargs": {
#     "class_name": "pg_modules.discriminator.ProjectedDiscriminator",
#     "diffaug": true,
#     "interp224": false,
#     "backbone_kwargs": {
#       "cout": 64,
#       "expand": true,
#       "proj_type": 2,
#       "num_discs": 4,
#       "separable": false,
#       "cond": false
#     }
#   },
#   "run_dir": "training-runs/00001-fastgan-lsun_train_output_dir-gpus1-batch64-"
# }
#
# Output directory:    training-runs/00001-fastgan-lsun_train_output_dir-gpus1-batch64-
# Number of GPUs:      1
# Batch size:          64 images
# Training duration:   10000 kimg
# Dataset path:        /content/drive/MyDrive/Places/LUSN_dataset_bedroom/lsun_train_output_dir
# Dataset size:        8098 images
# Dataset resolution:  256
# Dataset labels:      False
# Dataset x-flips:     1
#
# Creating output directory...
# Loading training set...
#
# Num images:  16196
# Image shape: [3, 256, 256]
# Label shape: [0]
#
# Constructing networks...
#
# Generator              Parameters  Buffers  Output shape        Datatype
# ---                    ---         ---      ---                 ---
# mapping                -           -        [8, 1, 256]         float32
# synthesis.init.init    16785408    16385    [8, 2048, 4, 4]     float32
# synthesis.feat_8.0     -           -        [8, 2048, 8, 8]     float32
# synthesis.feat_8.1     37748736    20480    [8, 2048, 8, 8]     float32
# synthesis.feat_8.2     1           -        [8, 2048, 8, 8]     float32
# synthesis.feat_8.3     4096        4097     [8, 2048, 8, 8]     float32
# synthesis.feat_8.4     -           -        [8, 1024, 8, 8]     float32
# synthesis.feat_8.5     18874368    11264    [8, 2048, 8, 8]     float32
# synthesis.feat_8.6     1           -        [8, 2048, 8, 8]     float32
# synthesis.feat_8.7     4096        4097     [8, 2048, 8, 8]     float32
# synthesis.feat_8.8     -           -        [8, 1024, 8, 8]     float32
# synthesis.feat_16.0    -           -        [8, 1024, 16, 16]   float32
# synthesis.feat_16.1    9437184     10240    [8, 1024, 16, 16]   float32
# synthesis.feat_16.2    1           -        [8, 1024, 16, 16]   float32
# synthesis.feat_16.3    2048        2049     [8, 1024, 16, 16]   float32
# synthesis.feat_16.4    -           -        [8, 512, 16, 16]    float32
# synthesis.feat_16.5    4718592     5632     [8, 1024, 16, 16]   float32
# synthesis.feat_16.6    1           -        [8, 1024, 16, 16]   float32
# synthesis.feat_16.7    2048        2049     [8, 1024, 16, 16]   float32
# synthesis.feat_16.8    -           -        [8, 512, 16, 16]    float32
# synthesis.feat_32.0    -           -        [8, 512, 32, 32]    float32
# synthesis.feat_32.1    2359296     5120     [8, 512, 32, 32]    float32
# synthesis.feat_32.2    1           -        [8, 512, 32, 32]    float32
# synthesis.feat_32.3    1024        1025     [8, 512, 32, 32]    float32
# synthesis.feat_32.4    -           -        [8, 256, 32, 32]    float32
# synthesis.feat_32.5    1179648     2816     [8, 512, 32, 32]    float32
# synthesis.feat_32.6    1           -        [8, 512, 32, 32]    float32
# synthesis.feat_32.7    1024        1025     [8, 512, 32, 32]    float32
# synthesis.feat_32.8    -           -        [8, 256, 32, 32]    float32
# synthesis.feat_64.0    -           -        [8, 256, 64, 64]    float32
# synthesis.feat_64.1    1179648     2816     [8, 512, 64, 64]    float32
# synthesis.feat_64.2    1           -        [8, 512, 64, 64]    float32
# synthesis.feat_64.3    1024        1025     [8, 512, 64, 64]    float32
# synthesis.feat_64.4    -           -        [8, 256, 64, 64]    float32
# synthesis.feat_64.5    1179648     2816     [8, 512, 64, 64]    float32
# synthesis.feat_64.6    1           -        [8, 512, 64, 64]    float32
# synthesis.feat_64.7    1024        1025     [8, 512, 64, 64]    float32
# synthesis.feat_64.8    -           -        [8, 256, 64, 64]    float32
# synthesis.se_64.main   8454144     33536    [8, 256, 1, 1]      float32
# synthesis.se_64        -           -        [8, 256, 64, 64]    float32
# synthesis.feat_128.0   -           -        [8, 256, 128, 128]  float32
# synthesis.feat_128.1   589824      2560     [8, 256, 128, 128]  float32
# synthesis.feat_128.2   1           -        [8, 256, 128, 128]  float32
# synthesis.feat_128.3   512         513      [8, 256, 128, 128]  float32
# synthesis.feat_128.4   -           -        [8, 128, 128, 128]  float32
# synthesis.feat_128.5   294912      1408     [8, 256, 128, 128]  float32
# synthesis.feat_128.6   1           -        [8, 256, 128, 128]  float32
# synthesis.feat_128.7   512         513      [8, 256, 128, 128]  float32
# synthesis.feat_128.8   -           -        [8, 128, 128, 128]  float32
# synthesis.se_128.main  2113536     16768    [8, 128, 1, 1]      float32
# synthesis.se_128       -           -        [8, 128, 128, 128]  float32
# synthesis.feat_256.0   -           -        [8, 128, 256, 256]  float32
# synthesis.feat_256.1   147456      1280     [8, 128, 256, 256]  float32
# synthesis.feat_256.2   1           -        [8, 128, 256, 256]  float32
# synthesis.feat_256.3   256         257      [8, 128, 256, 256]  float32
# synthesis.feat_256.4   -           -        [8, 64, 256, 256]   float32
# synthesis.feat_256.5   73728       704      [8, 128, 256, 256]  float32
# synthesis.feat_256.6   1           -        [8, 128, 256, 256]  float32
# synthesis.feat_256.7   256         257      [8, 128, 256, 256]  float32
# synthesis.feat_256.8   -           -        [8, 64, 256, 256]   float32
# synthesis.se_256.main  528384      8384     [8, 64, 1, 1]       float32
# synthesis.se_256       -           -        [8, 64, 256, 256]   float32
# synthesis.to_big       1731        579      [8, 3, 256, 256]    float32
# ---                    ---         ---      ---                 ---
# Total                  105684175   160720   -                   -
#
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#
# ProjectedDiscriminator                                               Parameters  Buffers  Output shape       Datatype
# ---                                                                  ---         ---      ---                ---
# feature_network.pretrained.layer0.0                                  864         -        [8, 32, 128, 128]  float32
# feature_network.pretrained.layer0.1                                  64          65       [8, 32, 128, 128]  float32
# feature_network.pretrained.layer0.3                                  896         98       [8, 16, 128, 128]  float32
# feature_network.pretrained.layer0.4                                  13968       1062     [8, 24, 64, 64]    float32
# feature_network.pretrained.layer1.0                                  39712       1702     [8, 40, 32, 32]    float32
# feature_network.pretrained.layer2.0                                  198480      5289     [8, 80, 16, 16]    float32
# feature_network.pretrained.layer2.1                                  446784      7977     [8, 112, 16, 16]   float32
# feature_network.pretrained.layer3.0                                  1652640     18060    [8, 192, 8, 8]     float32
# feature_network.pretrained.layer3.1                                  605440      5251     [8, 320, 8, 8]     float32
# feature_network.scratch.layer0_ccm                                   1600        -        [8, 64, 64, 64]    float32
# feature_network.scratch.layer1_ccm                                   5248        -        [8, 128, 32, 32]   float32
# feature_network.scratch.layer2_ccm                                   28928       -        [8, 256, 16, 16]   float32
# feature_network.scratch.layer3_ccm                                   164352      -        [8, 512, 8, 8]     float32
# feature_network.scratch.layer3_csm.out_conv                          131328      -        [8, 256, 16, 16]   float32
# feature_network.scratch.layer2_csm.skip_add.activation_post_process  -           -        [8, 256, 16, 16]   float32
# feature_network.scratch.layer2_csm.out_conv                          32896       -        [8, 128, 32, 32]   float32
# feature_network.scratch.layer1_csm.skip_add.activation_post_process  -           -        [8, 128, 32, 32]   float32
# feature_network.scratch.layer1_csm.out_conv                          8256        -        [8, 64, 64, 64]    float32
# feature_network.scratch.layer0_csm.skip_add.activation_post_process  -           -        [8, 64, 64, 64]    float32
# feature_network.scratch.layer0_csm.out_conv                          4160        -        [8, 64, 128, 128]  float32
# discriminator.mini_discs.0.main                                      2829120     19269    [8, 1, 5, 5]       float32
# discriminator.mini_discs.1.main                                      2763392     18052    [8, 1, 5, 5]       float32
# discriminator.mini_discs.2.main                                      2631936     16643    [8, 1, 5, 5]       float32
# discriminator.mini_discs.3.main                                      2106880     13826    [8, 1, 5, 5]       float32
# discriminator                                                        -           -        [8, 100]           float32
# ---                                                                  ---         ---      ---                ---
# Total                                                                13666944    107294   -                  -
#
# Distributing across 1 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# Training for 10000 kimg...
#
# tick 0     kimg 0.1      time 1m 19s       sec/tick 22.1    sec/kimg 344.63  maintenance 56.6   cpumem 4.90   gpumem 11.12  reserved 12.16
# tick 1     kimg 4.1      time 9m 09s       sec/tick 448.4   sec/kimg 111.20  maintenance 21.9   cpumem 5.07   gpumem 7.39   reserved 10.84
# tick 2     kimg 8.1      time 17m 10s      sec/tick 448.3   sec/kimg 111.19  maintenance 32.8   cpumem 5.08   gpumem 7.39   reserved 10.84
# tick 3     kimg 12.2     time 25m 11s      sec/tick 448.3   sec/kimg 111.19  maintenance 32.7   cpumem 5.02   gpumem 7.38   reserved 10.84
# tick 4     kimg 16.2     time 33m 13s      sec/tick 448.6   sec/kimg 111.27  maintenance 33.5   cpumem 4.97   gpumem 7.43   reserved 10.84
# tick 5     kimg 20.2     time 41m 16s      sec/tick 449.0   sec/kimg 111.36  maintenance 33.7   cpumem 4.81   gpumem 7.38   reserved 10.84
# tick 6     kimg 24.3     time 49m 17s      sec/tick 448.8   sec/kimg 111.31  maintenance 32.6   cpumem 4.37   gpumem 7.38   reserved 10.84
# tick 7     kimg 28.3     time 57m 19s      sec/tick 448.5   sec/kimg 111.23  maintenance 32.8   cpumem 4.25   gpumem 7.39   reserved 10.84
# tick 8     kimg 32.3     time 1h 05m 19s   sec/tick 448.5   sec/kimg 111.22  maintenance 32.3   cpumem 4.20   gpumem 7.38   reserved 10.84
# tick 9     kimg 36.4     time 1h 13m 21s   sec/tick 448.6   sec/kimg 111.26  maintenance 33.2   cpumem 4.18   gpumem 7.38   reserved 10.84
# tick 10    kimg 40.4     time 1h 21m 23s   sec/tick 448.4   sec/kimg 111.22  maintenance 33.3   cpumem 4.16   gpumem 7.38   reserved 10.84
# tick 11    kimg 44.4     time 1h 29m 24s   sec/tick 448.4   sec/kimg 111.21  maintenance 32.8   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 12    kimg 48.4     time 1h 37m 25s   sec/tick 448.7   sec/kimg 111.29  maintenance 32.5   cpumem 4.14   gpumem 7.39   reserved 10.84
# tick 13    kimg 52.5     time 1h 45m 26s   sec/tick 448.4   sec/kimg 111.22  maintenance 32.4   cpumem 4.15   gpumem 7.39   reserved 10.84
# tick 14    kimg 56.5     time 1h 53m 27s   sec/tick 448.5   sec/kimg 111.25  maintenance 32.4   cpumem 4.16   gpumem 7.43   reserved 10.84
# tick 15    kimg 60.5     time 2h 01m 30s   sec/tick 448.6   sec/kimg 111.27  maintenance 34.2   cpumem 4.16   gpumem 7.38   reserved 10.84
# tick 16    kimg 64.6     time 2h 09m 31s   sec/tick 448.7   sec/kimg 111.28  maintenance 33.0   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 17    kimg 68.6     time 2h 17m 33s   sec/tick 448.8   sec/kimg 111.30  maintenance 32.4   cpumem 4.16   gpumem 7.45   reserved 10.84
# tick 18    kimg 72.6     time 2h 25m 33s   sec/tick 448.5   sec/kimg 111.23  maintenance 32.3   cpumem 4.16   gpumem 7.43   reserved 10.84
# tick 19    kimg 76.7     time 2h 33m 34s   sec/tick 448.7   sec/kimg 111.29  maintenance 32.1   cpumem 4.16   gpumem 7.38   reserved 10.84
# tick 20    kimg 80.7     time 2h 41m 36s   sec/tick 448.2   sec/kimg 111.17  maintenance 33.0   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 21    kimg 84.7     time 2h 49m 38s   sec/tick 448.8   sec/kimg 111.31  maintenance 33.5   cpumem 4.16   gpumem 7.38   reserved 10.84
# tick 22    kimg 88.8     time 2h 57m 39s   sec/tick 448.5   sec/kimg 111.23  maintenance 32.5   cpumem 4.16   gpumem 7.43   reserved 10.84
# tick 23    kimg 92.8     time 3h 05m 40s   sec/tick 448.6   sec/kimg 111.27  maintenance 32.4   cpumem 4.17   gpumem 7.44   reserved 10.84
# tick 24    kimg 96.8     time 3h 13m 41s   sec/tick 448.5   sec/kimg 111.23  maintenance 32.6   cpumem 4.14   gpumem 7.39   reserved 10.84
# tick 25    kimg 100.9    time 3h 21m 43s   sec/tick 448.5   sec/kimg 111.24  maintenance 33.9   cpumem 4.14   gpumem 7.43   reserved 10.84
# tick 26    kimg 104.9    time 3h 29m 45s   sec/tick 448.5   sec/kimg 111.23  maintenance 33.1   cpumem 4.14   gpumem 7.38   reserved 10.84
# tick 27    kimg 108.9    time 3h 37m 45s   sec/tick 448.3   sec/kimg 111.19  maintenance 32.0   cpumem 4.14   gpumem 7.38   reserved 10.84
# tick 28    kimg 113.0    time 3h 45m 46s   sec/tick 448.4   sec/kimg 111.22  maintenance 32.6   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 29    kimg 117.0    time 3h 53m 47s   sec/tick 448.3   sec/kimg 111.19  maintenance 32.4   cpumem 4.16   gpumem 7.44   reserved 10.84
# tick 30    kimg 121.0    time 4h 01m 48s   sec/tick 448.4   sec/kimg 111.20  maintenance 32.7   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 31    kimg 125.1    time 4h 09m 49s   sec/tick 448.4   sec/kimg 111.21  maintenance 32.5   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 32    kimg 129.1    time 4h 17m 49s   sec/tick 448.1   sec/kimg 111.13  maintenance 31.9   cpumem 4.16   gpumem 7.38   reserved 10.84
# tick 33    kimg 133.1    time 4h 25m 50s   sec/tick 448.5   sec/kimg 111.24  maintenance 32.2   cpumem 4.19   gpumem 7.39   reserved 10.84
# tick 34    kimg 137.2    time 4h 33m 50s   sec/tick 448.6   sec/kimg 111.26  maintenance 32.3   cpumem 4.14   gpumem 7.39   reserved 10.84
# tick 35    kimg 141.2    time 4h 41m 52s   sec/tick 448.4   sec/kimg 111.20  maintenance 32.8   cpumem 4.18   gpumem 7.43   reserved 10.84
# tick 36    kimg 145.2    time 4h 49m 53s   sec/tick 448.4   sec/kimg 111.21  maintenance 33.1   cpumem 4.16   gpumem 7.44   reserved 10.84
# tick 37    kimg 149.2    time 4h 57m 54s   sec/tick 448.2   sec/kimg 111.15  maintenance 32.5   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 38    kimg 153.3    time 5h 05m 54s   sec/tick 448.2   sec/kimg 111.15  maintenance 32.3   cpumem 4.16   gpumem 7.44   reserved 10.84
# tick 39    kimg 157.3    time 5h 13m 56s   sec/tick 448.3   sec/kimg 111.19  maintenance 32.8   cpumem 4.17   gpumem 7.44   reserved 10.84
# tick 40    kimg 161.3    time 5h 21m 56s   sec/tick 448.2   sec/kimg 111.16  maintenance 32.4   cpumem 4.14   gpumem 7.39   reserved 10.84
# tick 41    kimg 165.4    time 5h 29m 57s   sec/tick 448.7   sec/kimg 111.28  maintenance 32.1   cpumem 4.17   gpumem 7.43   reserved 10.84
# tick 42    kimg 169.4    time 5h 37m 58s   sec/tick 448.7   sec/kimg 111.29  maintenance 32.7   cpumem 4.16   gpumem 7.43   reserved 10.84
# tick 43    kimg 173.4    time 5h 45m 59s   sec/tick 448.8   sec/kimg 111.31  maintenance 32.3   cpumem 4.16   gpumem 7.43   reserved 10.84
# tick 44    kimg 177.5    time 5h 54m 01s   sec/tick 448.9   sec/kimg 111.32  maintenance 32.3   cpumem 4.18   gpumem 7.43   reserved 10.84
# tick 45    kimg 181.5    time 6h 02m 01s   sec/tick 447.9   sec/kimg 111.09  maintenance 32.3   cpumem 4.21   gpumem 7.39   reserved 10.84
# tick 46    kimg 185.5    time 6h 10m 02s   sec/tick 448.6   sec/kimg 111.26  maintenance 32.7   cpumem 4.18   gpumem 7.38   reserved 10.84
# tick 47    kimg 189.6    time 6h 18m 03s   sec/tick 447.1   sec/kimg 110.88  maintenance 33.3   cpumem 4.17   gpumem 7.43   reserved 10.84
# tick 48    kimg 193.6    time 6h 26m 02s   sec/tick 447.1   sec/kimg 110.89  maintenance 32.6   cpumem 4.17   gpumem 7.39   reserved 10.84
# tick 49    kimg 197.6    time 6h 34m 03s   sec/tick 448.1   sec/kimg 111.14  maintenance 32.9   cpumem 4.14   gpumem 7.44   reserved 10.84
# tick 50    kimg 201.7    time 6h 42m 04s   sec/tick 447.7   sec/kimg 111.03  maintenance 32.7   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 51    kimg 205.7    time 6h 50m 03s   sec/tick 447.2   sec/kimg 110.92  maintenance 32.4   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 52    kimg 209.7    time 6h 58m 03s   sec/tick 447.4   sec/kimg 110.97  maintenance 32.6   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 53    kimg 213.8    time 7h 06m 04s   sec/tick 447.7   sec/kimg 111.04  maintenance 32.7   cpumem 4.16   gpumem 7.43   reserved 10.84
# tick 54    kimg 217.8    time 7h 14m 04s   sec/tick 447.3   sec/kimg 110.93  maintenance 33.4   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 55    kimg 221.8    time 7h 22m 04s   sec/tick 447.5   sec/kimg 110.99  maintenance 32.5   cpumem 4.14   gpumem 7.39   reserved 10.84
# tick 56    kimg 225.9    time 7h 30m 05s   sec/tick 447.6   sec/kimg 111.00  maintenance 32.9   cpumem 4.17   gpumem 7.39   reserved 10.84
# tick 57    kimg 229.9    time 7h 38m 05s   sec/tick 447.1   sec/kimg 110.90  maintenance 33.2   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 58    kimg 233.9    time 7h 46m 05s   sec/tick 447.5   sec/kimg 110.98  maintenance 32.7   cpumem 4.16   gpumem 7.38   reserved 10.84
# tick 59    kimg 238.0    time 7h 54m 05s   sec/tick 447.3   sec/kimg 110.93  maintenance 32.5   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 60    kimg 242.0    time 8h 02m 06s   sec/tick 447.4   sec/kimg 110.96  maintenance 33.2   cpumem 4.16   gpumem 7.39   reserved 10.84
# tick 61    kimg 246.0    time 8h 10m 08s   sec/tick 449.5   sec/kimg 111.49  maintenance 32.7   cpumem 4.23   gpumem 7.39   reserved 10.84
# tick 62    kimg 250.0    time 8h 18m 09s   sec/tick 447.3   sec/kimg 110.94  maintenance 33.3   cpumem 4.15   gpumem 7.38   reserved 10.84
# tick 63    kimg 254.1    time 8h 26m 09s   sec/tick 447.3   sec/kimg 110.95  maintenance 33.0   cpumem 4.16   gpumem 7.44   reserved 10.84
# tick 64    kimg 258.1    time 8h 34m 10s   sec/tick 449.0   sec/kimg 111.35  maintenance 32.6   cpumem 4.16   gpumem 7.39   reserved 10.84

# %% [markdown]
# To inspect the samples, click on the folder symbol on the left and navigate to
#
# ```projected_gan/training-runs/YOUR_RUN```
#
# The files ```fakesXXXXXX.png``` are the samples for a fixed noise vector at point.

# %%
# !python calc_metrics.py --metrics=fid50k_full --data=/content/drive/MyDrive/Places/Projected-GAN/projected_gan/training-runs/00001-fastgan-lsun_train_output_dir-gpus1-batch64-  \
--network=/content/drive/MyDrive/Places/Projected-GAN/projected_gan/training-runs/00001-fastgan-lsun_train_output_dir-gpus1-batch64-/network-snapshot.pkl
# Out:
# Loading network from "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/training-runs/00001-fastgan-lsun_train_output_dir-gpus1-batch64-/network-snapshot.pkl"...
# Dataset options:
# {
#   "class_name": "training.dataset.ImageFolderDataset",
#   "path": "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/training-runs/00001-fastgan-lsun_train_output_dir-gpus1-batch64-",
#   "resolution": 256,
#   "use_labels": false
# }
# Launching processes...
#
# Generator              Parameters  Buffers  Output shape        Datatype
# ---                    ---         ---      ---                 ---
# mapping                -           -        [1, 1, 256]         float32
# synthesis.init.init    16785408    16385    [1, 2048, 4, 4]     float32
# synthesis.feat_8.0     -           -        [1, 2048, 8, 8]     float32
# synthesis.feat_8.1     37748736    20480    [1, 2048, 8, 8]     float32
# synthesis.feat_8.2     1           -        [1, 2048, 8, 8]     float32
# synthesis.feat_8.3     4096        4097     [1, 2048, 8, 8]     float32
# synthesis.feat_8.4     -           -        [1, 1024, 8, 8]     float32
# synthesis.feat_8.5     18874368    11264    [1, 2048, 8, 8]     float32
# synthesis.feat_8.6     1           -        [1, 2048, 8, 8]     float32
# synthesis.feat_8.7     4096        4097     [1, 2048, 8, 8]     float32
# synthesis.feat_8.8     -           -        [1, 1024, 8, 8]     float32
# synthesis.feat_16.0    -           -        [1, 1024, 16, 16]   float32
# synthesis.feat_16.1    9437184     10240    [1, 1024, 16, 16]   float32
# synthesis.feat_16.2    1           -        [1, 1024, 16, 16]   float32
# synthesis.feat_16.3    2048        2049     [1, 1024, 16, 16]   float32
# synthesis.feat_16.4    -           -        [1, 512, 16, 16]    float32
# synthesis.feat_16.5    4718592     5632     [1, 1024, 16, 16]   float32
# synthesis.feat_16.6    1           -        [1, 1024, 16, 16]   float32
# synthesis.feat_16.7    2048        2049     [1, 1024, 16, 16]   float32
# synthesis.feat_16.8    -           -        [1, 512, 16, 16]    float32
# synthesis.feat_32.0    -           -        [1, 512, 32, 32]    float32
# synthesis.feat_32.1    2359296     5120     [1, 512, 32, 32]    float32
# synthesis.feat_32.2    1           -        [1, 512, 32, 32]    float32
# synthesis.feat_32.3    1024        1025     [1, 512, 32, 32]    float32
# synthesis.feat_32.4    -           -        [1, 256, 32, 32]    float32
# synthesis.feat_32.5    1179648     2816     [1, 512, 32, 32]    float32
# synthesis.feat_32.6    1           -        [1, 512, 32, 32]    float32
# synthesis.feat_32.7    1024        1025     [1, 512, 32, 32]    float32
# synthesis.feat_32.8    -           -        [1, 256, 32, 32]    float32
# synthesis.feat_64.0    -           -        [1, 256, 64, 64]    float32
# synthesis.feat_64.1    1179648     2816     [1, 512, 64, 64]    float32
# synthesis.feat_64.2    1           -        [1, 512, 64, 64]    float32
# synthesis.feat_64.3    1024        1025     [1, 512, 64, 64]    float32
# synthesis.feat_64.4    -           -        [1, 256, 64, 64]    float32
# synthesis.feat_64.5    1179648     2816     [1, 512, 64, 64]    float32
# synthesis.feat_64.6    1           -        [1, 512, 64, 64]    float32
# synthesis.feat_64.7    1024        1025     [1, 512, 64, 64]    float32
# synthesis.feat_64.8    -           -        [1, 256, 64, 64]    float32
# synthesis.se_64.main   8454144     33536    [1, 256, 1, 1]      float32
# synthesis.se_64        -           -        [1, 256, 64, 64]    float32
# synthesis.feat_128.0   -           -        [1, 256, 128, 128]  float32
# synthesis.feat_128.1   589824      2560     [1, 256, 128, 128]  float32
# synthesis.feat_128.2   1           -        [1, 256, 128, 128]  float32
# synthesis.feat_128.3   512         513      [1, 256, 128, 128]  float32
# synthesis.feat_128.4   -           -        [1, 128, 128, 128]  float32
# synthesis.feat_128.5   294912      1408     [1, 256, 128, 128]  float32
# synthesis.feat_128.6   1           -        [1, 256, 128, 128]  float32
# synthesis.feat_128.7   512         513      [1, 256, 128, 128]  float32
# synthesis.feat_128.8   -           -        [1, 128, 128, 128]  float32
# synthesis.se_128.main  2113536     16768    [1, 128, 1, 1]      float32
# synthesis.se_128       -           -        [1, 128, 128, 128]  float32
# synthesis.feat_256.0   -           -        [1, 128, 256, 256]  float32
# synthesis.feat_256.1   147456      1280     [1, 128, 256, 256]  float32
# synthesis.feat_256.2   1           -        [1, 128, 256, 256]  float32
# synthesis.feat_256.3   256         257      [1, 128, 256, 256]  float32
# synthesis.feat_256.4   -           -        [1, 64, 256, 256]   float32
# synthesis.feat_256.5   73728       704      [1, 128, 256, 256]  float32
# synthesis.feat_256.6   1           -        [1, 128, 256, 256]  float32
# synthesis.feat_256.7   256         257      [1, 128, 256, 256]  float32
# synthesis.feat_256.8   -           -        [1, 64, 256, 256]   float32
# synthesis.se_256.main  528384      8384     [1, 64, 1, 1]       float32
# synthesis.se_256       -           -        [1, 64, 256, 256]   float32
# synthesis.to_big       1731        579      [1, 3, 256, 256]    float32
# ---                    ---         ---      ---                 ---
# Total                  105684175   160720   -                   -
#
# Calculating fid50k_full...
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/calc_metrics.py", line 186, in <module>
#     calc_metrics() # pylint: disable=no-value-for-parameter
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1130, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1055, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 1404, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.9/dist-packages/click/core.py", line 760, in invoke
#     return __callback(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/click/decorators.py", line 26, in new_func
#     return f(get_current_context(), *args, **kwargs)
#   File "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/calc_metrics.py", line 179, in calc_metrics
#     subprocess_fn(rank=0, args=args, temp_dir=temp_dir)
#   File "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/calc_metrics.py", line 66, in subprocess_fn
#     result_dict = metric_main.calc_metric(metric=metric, G=G, dataset_kwargs=args.dataset_kwargs,
#   File "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/metrics/metric_main.py", line 43, in calc_metric
#     results = _metric_dict[metric](opts)
#   File "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/metrics/metric_main.py", line 83, in fid50k_full
#     fid = frechet_inception_distance.compute_fid(opts, max_real=None, num_gen=50000)
#   File "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/metrics/frechet_inception_distance.py", line 25, in compute_fid
#     mu_real, sigma_real = metric_utils.compute_feature_stats_for_dataset(
#   File "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/metrics/metric_utils.py", line 201, in compute_feature_stats_for_dataset
#     dataset = dnnlib.util.construct_class_by_name(**opts.dataset_kwargs)
#   File "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/dnnlib/util.py", line 303, in construct_class_by_name
#     return call_func_by_name(*args, func_name=class_name, **kwargs)
#   File "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/dnnlib/util.py", line 298, in call_func_by_name
#     return func_obj(*args, **kwargs)
#   File "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/training/dataset.py", line 196, in __init__
#     raise IOError('Image files do not match the specified resolution')
# OSError: Image files do not match the specified resolution

# %%
# !python calc_metrics.py --help
# Out:
# Usage: calc_metrics.py [OPTIONS]
#
#   Calculate quality metrics for previous training
#   run or pretrained network pickle.
#
#   Examples:
#
#   # Previous training run: look up options automatically, save result to JSONL file.
#   python calc_metrics.py --metrics=eqt50k_int,eqr50k \
#       --network=~/training-runs/00000-stylegan3-r-mydataset/network-snapshot-000000.pkl
#
#   # Pre-trained network pickle: specify dataset explicitly, print result to stdout.
#   python calc_metrics.py --metrics=fid50k_full --data=~/datasets/ffhq-1024x1024.zip --mirror=1 \
#       --network=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-t-ffhq-1024x1024.pkl
#
#   Recommended metrics:
#     fid50k_full  Frechet inception distance against the full dataset.
#     kid50k_full  Kernel inception distance against the full dataset.
#     pr50k3_full  Precision and recall againt the full dataset.
#     ppl2_wend    Perceptual path length in W, endpoints, full image.
#     eqt50k_int   Equivariance w.r.t. integer translation (EQ-T).
#     eqt50k_frac  Equivariance w.r.t. fractional translation (EQ-T_frac).
#     eqr50k       Equivariance w.r.t. rotation (EQ-R).
#
#   Legacy metrics:
#     fid50k       Frechet inception distance against 50k real images.
#     kid50k       Kernel inception distance against 50k real images.
#     pr50k3       Precision and recall against 50k real images.
#     is50k        Inception score for CIFAR-10.
#
# Options:
#   --network PATH               Network pickle
#                                filename or URL
#                                [required]
#   --metrics [NAME|A,B,C|none]  Quality metrics
#                                [default:
#                                fid50k_full]
#   --data [ZIP|DIR]             Dataset to evaluate
#                                against  [default:
#                                look up]
#   --mirror BOOL                Enable dataset
#                                x-flips  [default:
#                                look up]
#   --gpus INT                   Number of GPUs to
#                                use  [default: 1]
#   --verbose BOOL               Print optional
#                                information
#                                [default: True]
#   --help                       Show this message
#                                and exit.

# %%
# !python calc_metrics.py --metrics=fid50k_full --network=/content/drive/MyDrive/Places/Projected-GAN/projected_gan/training-runs/00001-fastgan-lsun_train_output_dir-gpus1-batch64-/network-snapshot.pkl
# Out:
# Loading network from "/content/drive/MyDrive/Places/Projected-GAN/projected_gan/training-runs/00001-fastgan-lsun_train_output_dir-gpus1-batch64-/network-snapshot.pkl"...
# Dataset options:
# {
#   "class_name": "training.dataset.ImageFolderDataset",
#   "path": "/content/drive/MyDrive/Places/LUSN_dataset_bedroom/lsun_train_output_dir",
#   "use_labels": false,
#   "max_size": 8098,
#   "xflip": 1,
#   "resolution": 256,
#   "random_seed": 0
# }
# Launching processes...
#
# Generator              Parameters  Buffers  Output shape        Datatype
# ---                    ---         ---      ---                 ---
# mapping                -           -        [1, 1, 256]         float32
# synthesis.init.init    16785408    16385    [1, 2048, 4, 4]     float32
# synthesis.feat_8.0     -           -        [1, 2048, 8, 8]     float32
# synthesis.feat_8.1     37748736    20480    [1, 2048, 8, 8]     float32
# synthesis.feat_8.2     1           -        [1, 2048, 8, 8]     float32
# synthesis.feat_8.3     4096        4097     [1, 2048, 8, 8]     float32
# synthesis.feat_8.4     -           -        [1, 1024, 8, 8]     float32
# synthesis.feat_8.5     18874368    11264    [1, 2048, 8, 8]     float32
# synthesis.feat_8.6     1           -        [1, 2048, 8, 8]     float32
# synthesis.feat_8.7     4096        4097     [1, 2048, 8, 8]     float32
# synthesis.feat_8.8     -           -        [1, 1024, 8, 8]     float32
# synthesis.feat_16.0    -           -        [1, 1024, 16, 16]   float32
# synthesis.feat_16.1    9437184     10240    [1, 1024, 16, 16]   float32
# synthesis.feat_16.2    1           -        [1, 1024, 16, 16]   float32
# synthesis.feat_16.3    2048        2049     [1, 1024, 16, 16]   float32
# synthesis.feat_16.4    -           -        [1, 512, 16, 16]    float32
# synthesis.feat_16.5    4718592     5632     [1, 1024, 16, 16]   float32
# synthesis.feat_16.6    1           -        [1, 1024, 16, 16]   float32
# synthesis.feat_16.7    2048        2049     [1, 1024, 16, 16]   float32
# synthesis.feat_16.8    -           -        [1, 512, 16, 16]    float32
# synthesis.feat_32.0    -           -        [1, 512, 32, 32]    float32
# synthesis.feat_32.1    2359296     5120     [1, 512, 32, 32]    float32
# synthesis.feat_32.2    1           -        [1, 512, 32, 32]    float32
# synthesis.feat_32.3    1024        1025     [1, 512, 32, 32]    float32
# synthesis.feat_32.4    -           -        [1, 256, 32, 32]    float32
# synthesis.feat_32.5    1179648     2816     [1, 512, 32, 32]    float32
# synthesis.feat_32.6    1           -        [1, 512, 32, 32]    float32
# synthesis.feat_32.7    1024        1025     [1, 512, 32, 32]    float32
# synthesis.feat_32.8    -           -        [1, 256, 32, 32]    float32
# synthesis.feat_64.0    -           -        [1, 256, 64, 64]    float32
# synthesis.feat_64.1    1179648     2816     [1, 512, 64, 64]    float32
# synthesis.feat_64.2    1           -        [1, 512, 64, 64]    float32
# synthesis.feat_64.3    1024        1025     [1, 512, 64, 64]    float32
# synthesis.feat_64.4    -           -        [1, 256, 64, 64]    float32
# synthesis.feat_64.5    1179648     2816     [1, 512, 64, 64]    float32
# synthesis.feat_64.6    1           -        [1, 512, 64, 64]    float32
# synthesis.feat_64.7    1024        1025     [1, 512, 64, 64]    float32
# synthesis.feat_64.8    -           -        [1, 256, 64, 64]    float32
# synthesis.se_64.main   8454144     33536    [1, 256, 1, 1]      float32
# synthesis.se_64        -           -        [1, 256, 64, 64]    float32
# synthesis.feat_128.0   -           -        [1, 256, 128, 128]  float32
# synthesis.feat_128.1   589824      2560     [1, 256, 128, 128]  float32
# synthesis.feat_128.2   1           -        [1, 256, 128, 128]  float32
# synthesis.feat_128.3   512         513      [1, 256, 128, 128]  float32
# synthesis.feat_128.4   -           -        [1, 128, 128, 128]  float32
# synthesis.feat_128.5   294912      1408     [1, 256, 128, 128]  float32
# synthesis.feat_128.6   1           -        [1, 256, 128, 128]  float32
# synthesis.feat_128.7   512         513      [1, 256, 128, 128]  float32
# synthesis.feat_128.8   -           -        [1, 128, 128, 128]  float32
# synthesis.se_128.main  2113536     16768    [1, 128, 1, 1]      float32
# synthesis.se_128       -           -        [1, 128, 128, 128]  float32
# synthesis.feat_256.0   -           -        [1, 128, 256, 256]  float32
# synthesis.feat_256.1   147456      1280     [1, 128, 256, 256]  float32
# synthesis.feat_256.2   1           -        [1, 128, 256, 256]  float32
# synthesis.feat_256.3   256         257      [1, 128, 256, 256]  float32
# synthesis.feat_256.4   -           -        [1, 64, 256, 256]   float32
# synthesis.feat_256.5   73728       704      [1, 128, 256, 256]  float32
# synthesis.feat_256.6   1           -        [1, 128, 256, 256]  float32
# synthesis.feat_256.7   256         257      [1, 128, 256, 256]  float32
# synthesis.feat_256.8   -           -        [1, 64, 256, 256]   float32
# synthesis.se_256.main  528384      8384     [1, 64, 1, 1]       float32
# synthesis.se_256       -           -        [1, 64, 256, 256]   float32
# synthesis.to_big       1731        579      [1, 3, 256, 256]    float32
# ---                    ---         ---      ---                 ---
# Total                  105684175   160720   -                   -
#
# Calculating fid50k_full...
# Calculating the stats for this dataset the first time
#
# Saving them to ./dnnlib/gan-metrics/lsun_train_output_dir-inception-2015-12-05-542491d5132cc91b7fe17f11204f4997.pkl
# Downloading https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/metrics/inception-2015-12-05.pkl ... done
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#  12%|#1        | 15/127 [01:59<01:44,  1.07it/s]dataset features    items 1024    time 2m 05s       ms/item 121.94
#  24%|##4       | 31/127 [02:05<00:33,  2.86it/s]dataset features    items 2048    time 2m 11s       ms/item 6.18
#  37%|###7      | 47/127 [02:10<00:25,  3.09it/s]dataset features    items 3072    time 2m 16s       ms/item 4.93
#  50%|####9     | 63/127 [02:16<00:25,  2.52it/s]dataset features    items 4096    time 2m 22s       ms/item 5.42
#  62%|######2   | 79/127 [02:22<00:15,  3.07it/s]dataset features    items 5120    time 2m 28s       ms/item 5.82
#  75%|#######4  | 95/127 [02:27<00:10,  3.07it/s]dataset features    items 6144    time 2m 33s       ms/item 5.00
#  87%|########7 | 111/127 [02:33<00:06,  2.31it/s]dataset features    items 7168    time 2m 39s       ms/item 5.94
#  99%|#########9| 126/127 [02:38<00:00,  3.57it/s]dataset features    items 8098    time 2m 44s       ms/item 5.22
# 100%|##########| 127/127 [02:39<00:00,  1.26s/it]
# generator features  items 1024    time 28s          ms/item 27.38
# generator features  items 2048    time 57s          ms/item 27.89
# generator features  items 3072    time 1m 25s       ms/item 27.75
# generator features  items 4096    time 1m 53s       ms/item 27.57
# generator features  items 5120    time 2m 22s       ms/item 27.71
# generator features  items 6144    time 2m 50s       ms/item 27.68
# generator features  items 7168    time 3m 18s       ms/item 27.68
# generator features  items 8192    time 3m 47s       ms/item 27.62
# generator features  items 9216    time 4m 15s       ms/item 27.69
# generator features  items 10240   time 4m 43s       ms/item 27.66
# generator features  items 11264   time 5m 12s       ms/item 27.70
# generator features  items 12288   time 5m 40s       ms/item 27.77
# generator features  items 13312   time 6m 08s       ms/item 27.71
# generator features  items 14336   time 6m 37s       ms/item 27.72
# generator features  items 15360   time 7m 05s       ms/item 27.68
# generator features  items 16384   time 7m 34s       ms/item 27.69
# generator features  items 17408   time 8m 02s       ms/item 27.65
# generator features  items 18432   time 8m 30s       ms/item 27.63
# generator features  items 19456   time 8m 58s       ms/item 27.66
# generator features  items 20480   time 9m 27s       ms/item 27.73
# generator features  items 21504   time 9m 55s       ms/item 27.63
# generator features  items 22528   time 10m 24s      ms/item 27.79
# generator features  items 23552   time 10m 52s      ms/item 27.74
# generator features  items 24576   time 11m 20s      ms/item 27.71
# generator features  items 25600   time 11m 49s      ms/item 27.65
# generator features  items 26624   time 12m 17s      ms/item 27.76
# generator features  items 27648   time 12m 46s      ms/item 27.75
# generator features  items 28672   time 13m 14s      ms/item 27.74
# generator features  items 29696   time 13m 42s      ms/item 27.66
# generator features  items 30720   time 14m 11s      ms/item 27.70
# generator features  items 31744   time 14m 39s      ms/item 27.70
# generator features  items 32768   time 15m 07s      ms/item 27.76
# generator features  items 33792   time 15m 36s      ms/item 27.78
# generator features  items 34816   time 16m 04s      ms/item 27.69
# generator features  items 35840   time 16m 33s      ms/item 27.68
# generator features  items 36864   time 17m 01s      ms/item 27.67
# generator features  items 37888   time 17m 29s      ms/item 27.67
# generator features  items 38912   time 17m 58s      ms/item 27.80
# generator features  items 39936   time 18m 26s      ms/item 27.70
# generator features  items 40960   time 18m 54s      ms/item 27.67
# generator features  items 41984   time 19m 23s      ms/item 27.66
# generator features  items 43008   time 19m 51s      ms/item 27.64
# generator features  items 44032   time 20m 19s      ms/item 27.70
# generator features  items 45056   time 20m 48s      ms/item 27.68
# generator features  items 46080   time 21m 16s      ms/item 27.64
# generator features  items 47104   time 21m 44s      ms/item 27.60
# generator features  items 48128   time 22m 13s      ms/item 27.63
# generator features  items 49152   time 22m 41s      ms/item 27.75
# generator features  items 50000   time 23m 06s      ms/item 29.27
# {"results": {"fid50k_full": 13.564056627928156}, "metric": "fid50k_full", "total_time": 1670.8500905036926, "total_time_str": "27m 51s", "num_gpus": 1, "snapshot_pkl": "network-snapshot.pkl", "timestamp": 1681145478.585002}
#
# Exiting...
